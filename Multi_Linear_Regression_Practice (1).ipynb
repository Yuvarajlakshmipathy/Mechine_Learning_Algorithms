# %% [markdown]
# Multi Linear Regression : Multiple linear regression is a regression model that estimates the relationship between a quantitative dependent variable and two or more independent variables using a straight line.

# %% [markdown]
# Pandas : Pandas is a python library used for data manipulation and analysis, particularly for working with stuctured data such as tables and time series.

# %% [markdown]
# Numpy : Numpy is a python library used for numerical computing, providing support for large, multi-dimensional arrays and matrices , along with a collection of mathematical function to operate on these arrays efficiently.

# %% [markdown]
# Matplotlib : Matplotlib is a python library used for creating static, interactive, and animated visualizations in a variety of formats, such as line plots, scatter plots, histograms and more.

# %% [markdown]
# Seaborn : Seaborn is a python visualization library based on matplotlib, designed to make statistical plotting more attractive and information with fewer lines of code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
from google.colab import files
DF = files.upload()
# Out:
#      <input type="file" id="files-7bd80b67-fc84-4064-846a-8e193986656d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bd80b67-fc84-4064-846a-8e193986656d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
DF=pd.read_csv("Real estate.csv")

# %%
DF
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
DF_copy = DF.copy()

# %% [markdown]
# EDA = Exploratory Data Analysis:
#                   Which is the process of analyzing datasets to summarize their
#                   main characteristics, often using visual methods.

# %%
DF.shape
# Out:
# (414, 8)

# %%
DF.head(100)
# Out:
#      No  X1 transaction date  X2 house age  \
# 0     1             2012.917          32.0
# 1     2             2012.917          19.5
# 2     3             2013.583          13.3
# 3     4             2013.500          13.3
# 4     5             2012.833           5.0
# ..  ...                  ...           ...
# 95   96             2012.917           8.0
# 96   97             2013.417           6.4
# 97   98             2013.083          28.4
# 98   99             2013.417          16.4
# 99  100             2013.417           6.4
#
#     X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 84.87882                               10
# 1                                306.59470                                9
# 2                                561.98450                                5
# 3                                561.98450                                5
# ...

# %%
DF.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
DF.iloc[10:50]
# Out:
#     No  X1 transaction date  X2 house age  \
# 10  11             2013.083          34.8
# 11  12             2013.333           6.3
# 12  13             2012.917          13.0
# 13  14             2012.667          20.4
# 14  15             2013.500          13.2
# 15  16             2013.583          35.7
# 16  17             2013.250           0.0
# 17  18             2012.750          17.7
# 18  19             2013.417          16.9
# 19  20             2012.667           1.5
# 20  21             2013.417           4.5
# 21  22             2013.417          10.5
# 22  23             2012.917          14.7
# 23  24             2013.083          10.1
# 24  25             2013.000          39.6
# 25  26             2013.083          29.3
# 26  27             2012.667           3.1
# 27  28             2013.250          10.4
# 28  29             2013.500          19.2
# 29  30             2013.083           7.1
# 30  31             2013.500          25.9
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
DF.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
DF.isnull()
# Out:
#         No  X1 transaction date  X2 house age  \
# 0    False                False         False
# 1    False                False         False
# 2    False                False         False
# 3    False                False         False
# 4    False                False         False
# ..     ...                  ...           ...
# 409  False                False         False
# 410  False                False         False
# 411  False                False         False
# 412  False                False         False
# 413  False                False         False
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                     False                            False
# 1                                     False                            False
# 2                                     False                            False
# 3                                     False                            False
# ...

# %%
x = DF.iloc[:, :-1]

# %%
y = DF.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2, random_state=5)

# %%
x_test
# Out:
#       No  X1 transaction date  X2 house age  \
# 336  337             2012.833           5.1
# 140  141             2013.250          16.2
# 52    53             2013.583          32.1
# 75    76             2013.500          12.3
# 157  158             2013.250          16.1
# ..   ...                  ...           ...
# 60    61             2013.417          11.0
# 248  249             2013.000          19.0
# 329  330             2013.000          13.6
# 123  124             2013.417           0.0
# 317  318             2012.750          15.6
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 336                               1867.2330                                2
# 140                                289.3248                                5
# 52                                1438.5790                                3
# 75                                1360.1390                                1
# ...

# %%
y_test
# Out:
# 336    35.6
# 140    51.4
# 52     27.0
# 75     29.5
# 157    35.6
#        ...
# 60     21.3
# 248    22.3
# 329    19.2
# 123    45.5
# 317    37.5
# Name: Y house price of unit area, Length: 83, dtype: float64

# %% [markdown]
# sklearn : scikit-learn is a free software machine learning library for the Python programming language.

# %%
from sklearn.linear_model import LinearRegression

# %%
std_reg = LinearRegression()

# %%
std_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = std_reg.predict(x_test)

# %%
y_predict
# Out:
# array([37.94588235, 46.84105144, 35.75007504, 32.79594943, 42.82861507,
#        44.48055438, 52.82718833, 48.26553242, 35.29402613, 36.9810308 ,
#        40.79148169, 34.0794296 , 42.62254758, 38.49236427, 54.79335797,
#        38.47762453, 43.60049252, 41.26490193, 51.09475415, 50.6368343 ,
#        40.82076064, 15.77651144, 43.83390685, 47.82087977, 48.52976465,
#        42.7260463 , 40.48000445, 36.95019389, 19.19904373, 43.36756085,
#        47.24988204, 34.51405951, 36.06592188, 55.0653277 , 36.75163872,
#        12.99522787, 44.4036653 , 45.75945932, 36.76523791, 41.79746987,
#        36.41643832, 36.3204185 , 34.6609248 , 44.42759795, 48.14701613,
#        40.35013798, 30.77606141, 39.64948775, 40.32041203, 39.08557727,
#        12.03853125, 42.2688639 , 41.8500757 , 11.8226938 , 10.16403782,
#        40.44490315, 37.83242716, 36.57420341, 39.67626976, 31.83039249,
#        43.15928194, 24.51006658, 54.26797924, 31.35273753, 30.97784833,
# ...

# %%
sbn.regplot(x=y_test,y=y_predict,ci = None,color="blue")
plt.plot(x_train,std_reg.predict(x_train),color = "red")
plt.title("Real Estate")
plt.xlabel("x1 transaction date x2 house age x3 distance to the nearest MRT station x4 number of convenience stores x5 latitude x6 longtitud ")
plt.ylabel("Y house price of unit area ")
plt.show()

# %%
y_test
# Out:
# 336    35.6
# 140    51.4
# 52     27.0
# 75     29.5
# 157    35.6
#        ...
# 60     21.3
# 248    22.3
# 329    19.2
# 123    45.5
# 317    37.5
# Name: Y house price of unit area, Length: 83, dtype: float64

# %%
x_test
# Out:
#       No  X1 transaction date  X2 house age  \
# 336  337             2012.833           5.1
# 140  141             2013.250          16.2
# 52    53             2013.583          32.1
# 75    76             2013.500          12.3
# 157  158             2013.250          16.1
# ..   ...                  ...           ...
# 60    61             2013.417          11.0
# 248  249             2013.000          19.0
# 329  330             2013.000          13.6
# 123  124             2013.417           0.0
# 317  318             2012.750          15.6
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 336                               1867.2330                                2
# 140                                289.3248                                5
# 52                                1438.5790                                3
# 75                                1360.1390                                1
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %% [markdown]
# MAE = Mean Absolute Error:
#                MAE is a statistical metric used to measure the average magnitude of errors between predicted and actual values, regardless of their direction.

# %%
MAE = mean_absolute_error(y_test,y_predict)
print(MAE)
# Out:
# 5.558171415722324

# %% [markdown]
# MSE = Mean Squared Error:
#             MSE is a statistical measure of the average squared difference between predictedand actual values .

# %%
MSE = mean_squared_error(y_test,y_predict)
print(MSE)
# Out:
# 58.63382109599524

# %% [markdown]
# RMSE = Root Mean Squared Error:
#           which is a statistical measure of the square root of the average of squared difference between predicted and actual values .

# %%
RMSE = np.sqrt(MSE)
print(RMSE)
# Out:
# 7.657272431877766
