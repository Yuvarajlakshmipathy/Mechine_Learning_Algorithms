# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvarajlakshmipathy/Mechine_Learning_Algorithms/blob/main/MLR_with_evalution_mesures_implementation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MLR - Multi Linear Regression

# %% [markdown]
# Python libraies importing

# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %% [markdown]
# Data Uploding

# %%
from google.colab import files
upload_files = files.upload()
# Out:
#      <input type="file" id="files-6081126b-0bdc-4592-b948-7bcd2146f067" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6081126b-0bdc-4592-b948-7bcd2146f067">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("01Students.csv")

# %% [markdown]
# Data Shallow Copy

# %%
df_copy = df.copy()

# %%
df
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %%
df_copy
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %% [markdown]
# Data Preprossing

# %% [markdown]
# EDA - Exploratory Data Analysis

# %% [markdown]
# *Shape - Check the no of rows and colums of a data frame

# %%
df.shape
# Out:
# (30, 2)

# %% [markdown]
# *Data Sample View

# %%
df.head(5)
# Out:
#    Hours  Marks
# 0      0     34
# 1      1     36
# 2      1     33
# 3      1     39
# 4      1     42

# %%
df.tail()
# Out:
#     Hours  Marks
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %%
df.iloc[10:15]                         #Data Slicing
# Out:
#     Hours  Marks
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72

# %%
df.info()                              # Technical Enquiry of a data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   30 non-null     int64
#  1   Marks   30 non-null     int64
# dtypes: int64(2)
# memory usage: 608.0 bytes

# %%
df.describe()                  #Statistical report
# Out:
#            Hours      Marks
# count  30.000000  30.000000
# mean    5.200000  61.400000
# std     3.188341  17.734828
# min     0.000000  33.000000
# 25%     3.000000  45.250000
# 50%     5.000000  60.000000
# 75%     7.750000  77.000000
# max    11.000000  89.000000

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# Hours    0
# Marks    0
# dtype: int64

# %% [markdown]
# Split into X (Independent) and Y (predicted)

# %%
x = df.iloc[:, :-1]
y = df.iloc[: ,-1]

# %%
x
# Out:
#     Hours
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
# 5       2
# 6       2
# 7       3
# 8       3
# 9       3
# 10      3
# 11      4
# 12      4
# 13      4
# 14      5
# 15      5
# 16      6
# 17      6
# 18      7
# 19      7
# 20      7
# 21      7
# 22      8
# 23      8
# 24      9
# 25      9
# 26      9
# 27     10
# 28     10
# 29     11

# %%
y
# Out:
# 0     34
# 1     36
# 2     33
# 3     39
# 4     42
# 5     45
# 6     38
# 7     45
# 8     53
# 9     46
# 10    56
# 11    59
# 12    55
# 13    56
# 14    72
# 15    59
# 16    62
# 17    71
# 18    78
# 19    88
# 20    61
# 21    74
# 22    71
# 23    89
# 24    82
# 25    67
# 26    89
# 27    81
# 28    82
# 29    79
# Name: Marks, dtype: int64

# %% [markdown]
# Train Test Spilit

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.5,random_state=5)

# %%
y_test
# Out:
# 11    59
# 29    79
# 23    89
# 25    67
# 18    78
# 10    56
# 2     33
# 13    56
# 26    89
# 21    74
# 28    82
# 0     34
# 17    71
# 5     45
# 1     36
# Name: Marks, dtype: int64

# %%
x_test
# Out:
#     Hours
# 11      4
# 29     11
# 23      8
# 25      9
# 18      7
# 10      3
# 2       1
# 13      4
# 26      9
# 21      7
# 28     10
# 0       0
# 17      6
# 5       2
# 1       1

# %%
from sklearn.linear_model import LinearRegression

# %%
std_reg = LinearRegression()

# %%
std_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = std_reg.predict(x_test)

# %%
y_predict
# Out:
# array([54.76859504, 91.00413223, 75.47461629, 80.65112161, 70.29811098,
#        49.59208973, 39.2390791 , 54.76859504, 80.65112161, 70.29811098,
#        85.82762692, 34.06257379, 65.12160567, 44.41558442, 39.2390791 ])

# %% [markdown]
# Evalution

# %%
y_test
# Out:
# 11    59
# 29    79
# 23    89
# 25    67
# 18    78
# 10    56
# 2     33
# 13    56
# 26    89
# 21    74
# 28    82
# 0     34
# 17    71
# 5     45
# 1     36
# Name: Marks, dtype: int64

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
MAE = mean_absolute_error(y_test,y_predict)

# %%
MAE
# Out:
# 6.042345533254623

# %%
MSE = mean_squared_error(y_test,y_predict)

# %%
MSE
# Out:
# 54.37113798869726

# %%
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 7.373678728334809

# %%
LRMSE = np.log(RMSE)

# %%
LRMSE
# Out:
# 1.9979167306955976

# %% [markdown]
# Accuracy Measure

# %%
R2 = r2_score(y_test,y_predict)

# %%
R2
# Out:
# 0.8461890710186974
